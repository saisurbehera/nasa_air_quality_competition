# %%
# ls ../../data/processed

# %%
import glob
all_files = glob.glob("../../data/processed/*.json")

# %%
all_files
# Out:
# ['../../data/processed/20200520T025000_maiac_tpe_1.hdf.json',
#  '../../data/processed/20180405T034000_maiac_tpe_1.hdf.json',
#  '../../data/processed/20200520T025000_maiac_tpe_0.hdf.json',
#  '../../data/processed/20200803T055000_maiac_dl_0.hdf.json',
#  '../../data/processed/20201216T023500_maiac_tpe_0.hdf.json',
#  '../../data/processed/20180405T034000_maiac_tpe_0.hdf.json',
#  '../../data/processed/20181014T065500_maiac_dl_0.hdf.json',
#  '../../data/processed/20191130T202500_maiac_la_0.hdf.json',
#  '../../data/processed/20200104T192000_maiac_la_0.hdf.json',
#  '../../data/processed/20180616T191500_maiac_la_0.hdf.json',
#  '../../data/processed/20201220T035000_maiac_tpe_0.hdf.json',
#  '../../data/processed/20190204T060000_maiac_dl_0.hdf.json',
#  '../../data/processed/20190907T025000_maiac_tpe_1.hdf.json',
#  '../../data/processed/20180712T032500_maiac_tpe_0.hdf.json',
#  '../../data/processed/20180213T030500_maiac_tpe_0.hdf.json',
# ...

# %%
import json

with open(all_files[1],"r") as json_file:
    data = json_file.read()

# %%
data
# Out:
# ''
