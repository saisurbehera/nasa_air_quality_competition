# %%
import os
import re
import random
from datetime import datetime

from pathlib import Path
os.chdir('/content/drive/MyDrive/datadriven/airathon')
DATA_PATH = Path.cwd() / 'data'
RAW = DATA_PATH / 'raw'
PROCESSED = DATA_PATH / 'processed'

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import tensorflow as tf
from tensorflow import keras
from keras import layers

from tqdm import tqdm

# %%
train, test = {}, {}
locations = ['la', 'dl', 'tpe']

for loc in locations:
    train[loc] = pd.read_csv(str(PROCESSED / f'train_{loc}.csv'), parse_dates=['datetime', 'day']).sort_values(by=['datetime'])
    test[loc] = pd.read_csv(str(PROCESSED / f'test_{loc}.csv'), parse_dates=['datetime', 'day']).sort_values(by=['datetime'])
    

data = pd.concat([train['la'], train['dl'], train['tpe']]).dropna()
test_data = pd.concat([test['la'], test['dl'], test['tpe']])

target = np.array(data.pm25).reshape(-1,1)
target_scaler = MinMaxScaler()
target = target_scaler.fit_transform(target)

data.drop(columns=['datetime', 'pm25', 'day'], axis=1, inplace=True)
test_data.drop(columns=['datetime', 'value', 'day'], axis=1, inplace=True)

ohe_features = ['grid_id']
ohe_transformer = OneHotEncoder(handle_unknown='ignore')

num_features = ['Optical_Depth_047_mean',
       'Optical_Depth_047_min', 'Optical_Depth_047_max',
       'Optical_Depth_047_std', 'Optical_Depth_055_mean',
       'Optical_Depth_055_min', 'Optical_Depth_055_max',
       'Optical_Depth_055_std', 'AOD_Uncertainty_mean', 'AOD_Uncertainty_min',
       'AOD_Uncertainty_max', 'AOD_Uncertainty_std', 'Column_WV_mean',
       'Column_WV_min', 'Column_WV_max', 'Column_WV_std', 'cosSZA_mean',
       'cosSZA_min', 'cosSZA_max', 'cosSZA_std', 'cosVZA_mean', 'cosVZA_min',
       'cosVZA_max', 'cosVZA_std', 'RelAZ_mean', 'RelAZ_min', 'RelAZ_max',
       'RelAZ_std', 'Scattering_Angle_mean', 'Scattering_Angle_min',
       'Scattering_Angle_max', 'Scattering_Angle_std', 'Glint_Angle_mean',
       'Glint_Angle_min', 'Glint_Angle_max', 'Glint_Angle_std']

num_transformer = Pipeline(steps=[
                                  ('imputer', SimpleImputer(strategy='mean')), 
                                  ('scaler', MinMaxScaler())
                                  ])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_features),
        ('cat', ohe_transformer, ohe_features)])

data = preprocessor.fit_transform(data)
test_data = preprocessor.transform(test_data)

n_features = data.shape[1]

# %%
model = keras.Sequential([
    layers.Dense(64, activation=tf.nn.relu, input_shape=[n_features]),
    layers.Dropout(.3),
    layers.Dense(60, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(56, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(52, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(48, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(44, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(40, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(36, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(32, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(28, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(24, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(20, activation=tf.nn.relu),
    layers.Dropout(.3),
    layers.Dense(10, activation=tf.nn.relu),
    layers.Dense(1)
    ])

optimizer = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='mse', optimizer=optimizer, metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 64)                5120
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_30 (Dense)            (None, 60)                3900
#
#  dropout_1 (Dropout)         (None, 60)                0
#
#  dense_31 (Dense)            (None, 56)                3416
#
#  dropout_2 (Dropout)         (None, 56)                0
#
#  dense_32 (Dense)            (None, 52)                2964
#
#  dropout_3 (Dropout)         (None, 52)                0
#
#  dense_33 (Dense)            (None, 48)                2544
#
#  dropout_4 (Dropout)         (None, 48)                0
#
#  dense_34 (Dense)            (None, 44)                2156
#
#  dropout_5 (Dropout)         (None, 44)                0
#
#  dense_35 (Dense)            (None, 40)                1800
#
#  dropout_6 (Dropout)         (None, 40)                0
#
#  dense_36 (Dense)            (None, 36)                1476
#
#  dropout_7 (Dropout)         (None, 36)                0
#
#  dense_37 (Dense)            (None, 32)                1184
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_38 (Dense)            (None, 28)                924
#
#  dropout_9 (Dropout)         (None, 28)                0
#
#  dense_39 (Dense)            (None, 24)                696
#
#  dropout_10 (Dropout)        (None, 24)                0
#
#  dense_40 (Dense)            (None, 20)                500
#
#  dropout_11 (Dropout)        (None, 20)                0
#
#  dense_41 (Dense)            (None, 10)                210
#
#  dense_42 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 26,901
# Trainable params: 26,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(data[0:10])
# Out:
# array([[0.00040925],
#        [0.00066063],
#        [0.00021395],
#        [0.00038469],
#        [0.00023013],
#        [0.00031306],
#        [0.0013245 ],
#        [0.00035073],
#        [0.00052658],
#        [0.00070483]], dtype=float32)

# %%
EPOCHS = 100
batch_size = 64 

history = model.fit(data, target.reshape(-1,), epochs=EPOCHS, validation_split=0.2, batch_size=batch_size)
# Out:
# Epoch 1/100
# 196/196 [==============================] - 2s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 2/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 3/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 4/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 5/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 6/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 7/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 8/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 9/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 10/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 11/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 12/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 13/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 14/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 15/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 16/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 17/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 18/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 19/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 20/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 21/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 22/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 23/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 24/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 25/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 26/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 27/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 28/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 29/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 30/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 31/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 32/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 33/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 34/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 35/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 36/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 37/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 38/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 39/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 40/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 41/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 42/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 43/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 44/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 45/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 46/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 47/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 48/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 49/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 50/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 51/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 52/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 53/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 54/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 55/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 56/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 57/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 58/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 59/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 60/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 61/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 62/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 63/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 64/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 65/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 66/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 67/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 68/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 69/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 70/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 71/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 72/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 73/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 74/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 75/100
# 196/196 [==============================] - 1s 5ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 76/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 77/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 78/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 79/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 80/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 81/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 82/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 83/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 84/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 85/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 86/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 87/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 88/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 89/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 90/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 91/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 92/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 93/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 94/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 95/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 96/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 97/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 98/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 99/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 100/100
# 196/196 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0105 - val_mse: 0.0105

# %%
pred = model.predict(test_data)
pred = target_scaler.inverse_transform(pred)

test_df = pd.concat([test['la'], test['dl'], test['tpe']])
test_df.value = pred

submission = pd.read_csv(RAW / 'submission_format.csv', parse_dates=['datetime'])

# %%
for i in tqdm(range(len(submission))):
    sample = submission.iloc[i]
    if len(test_df[(test_df.datetime == sample.datetime) & (test_df.grid_id == sample.grid_id)]) != 1:
        print(len(test_df[(test_df.datetime == sample.datetime) & (test_df.grid_id == sample.grid_id)]))
        break 
        
    submission.loc[i, 'value'] = test_df[(test_df.datetime == sample.datetime) & (test_df.grid_id == sample.grid_id)].value.values[0]
# Out:
# 100%|██████████| 13504/13504 [00:49<00:00, 274.18it/s]

# %%
submission_format = pd.read_csv(RAW / 'submission_format.csv')
submission_format.value = submission.value
submission_format.to_csv(DATA_PATH / 'submission/feed_foward.csv', index=False)

# %%
WLSV_5011 = pd.read_csv(DATA_PATH / 'submission/WLSV_5011.csv')
feed_forward = pd.read_csv(DATA_PATH / 'submission/feed_forward.csv')
submission_format = pd.read_csv(RAW / 'submission_format.csv')
submission_format.value = (2/3)*(WLSV_5011.value) + (1/3)*(feed_forward.value)
submission_format.to_csv(DATA_PATH / 'submission/WLSV23_feed_fwd13.csv', index=False)
